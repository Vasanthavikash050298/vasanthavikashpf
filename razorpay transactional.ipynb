# %%
import pandas as pd
import matplotlib as mplot
import numpy as np
df=pd.read_csv(r"C:\Users\New\Desktop\portfolio project\pandas\razorpay_transactions_dataset.csv",)
df
# Out:
#      transaction_id merchant_id                           customer_id  \
# 0         TID000001     MID0039  bdd640fb-0667-4ad1-9c80-317fa3b1799d
# 1         TID000002     MID0029  23b8c1e9-3924-46de-beb1-3b9046685257
# 2         TID000003     MID0015  bd9c66b3-ad3c-4d6d-9a3d-1fa7bc8960a9
# 3         TID000004     MID0043  972a8469-1641-4f82-8b9d-2434e465e150
# 4         TID000005     MID0008  17fc695a-07a0-4a6e-8822-e8f36c031199
# ...             ...         ...                                   ...
# 4995      TID004996     MID0032  0f344fe1-c3c5-4bb5-a355-ce1655a47eab
# 4996      TID004997     MID0046  d11756d5-8c0d-4a8b-b448-a24723a86b61
# 4997      TID004998     MID0047  c1e158aa-ec96-4f27-9461-4433bbdf144c
# 4998      TID004999     MID0048  0ff4c2d6-e0d6-4081-a98d-c5f7a9d06567
# 4999      TID005000     MID0023  ce3fde9a-12aa-4ab4-be59-a0d13c5168b0
#
#        amount currency payment_method   status        timestamp device_type  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   transaction_id  5000 non-null   object
#  1   merchant_id     5000 non-null   object
#  2   customer_id     5000 non-null   object
#  3   amount          5000 non-null   float64
#  4   currency        5000 non-null   object
#  5   payment_method  5000 non-null   object
#  6   status          5000 non-null   object
#  7   timestamp       5000 non-null   object
#  8   device_type     5000 non-null   object
#  9   location        5000 non-null   object
# dtypes: float64(1), object(9)
# memory usage: 390.8+ KB

# %%
df.isnull().sum()#no null
# Out:
# transaction_id    0
# merchant_id       0
# customer_id       0
# amount            0
# currency          0
# payment_method    0
# status            0
# timestamp         0
# device_type       0
# location          0
# dtype: int64

# %%
print(df['amount'].max())
print(df['amount'].min())
print(df['currency'].value_counts())
print(df['payment_method'].value_counts())
print(df['status'].value_counts())
# Out:
# 13199.78
# 0.28
# currency
# INR    4747
# USD     253
# Name: count, dtype: int64
# payment_method
# Credit Card    1060
# UPI            1017
# Debit Card      992
# Net Banking     982
# Wallet          949
# Name: count, dtype: int64
# status
# Success     4338
# Failed       508
# Refunded     154
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['transaction_id', 'merchant_id', 'customer_id', 'amount', 'currency',
#        'payment_method', 'status', 'timestamp', 'device_type', 'location'],
#       dtype='object')

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      transaction_id merchant_id                           customer_id  \
# 0         TID000001     MID0039  bdd640fb-0667-4ad1-9c80-317fa3b1799d
# 1         TID000002     MID0029  23b8c1e9-3924-46de-beb1-3b9046685257
# 2         TID000003     MID0015  bd9c66b3-ad3c-4d6d-9a3d-1fa7bc8960a9
# 3         TID000004     MID0043  972a8469-1641-4f82-8b9d-2434e465e150
# 4         TID000005     MID0008  17fc695a-07a0-4a6e-8822-e8f36c031199
# ...             ...         ...                                   ...
# 4995      TID004996     MID0032  0f344fe1-c3c5-4bb5-a355-ce1655a47eab
# 4996      TID004997     MID0046  d11756d5-8c0d-4a8b-b448-a24723a86b61
# 4997      TID004998     MID0047  c1e158aa-ec96-4f27-9461-4433bbdf144c
# 4998      TID004999     MID0048  0ff4c2d6-e0d6-4081-a98d-c5f7a9d06567
# 4999      TID005000     MID0023  ce3fde9a-12aa-4ab4-be59-a0d13c5168b0
#
#        amount currency payment_method   status        timestamp device_type  \
# ...

# %%
df.head()
# Out:
#   transaction_id merchant_id                           customer_id   amount  \
# 0      TID000001     MID0039  bdd640fb-0667-4ad1-9c80-317fa3b1799d   842.15
# 1      TID000002     MID0029  23b8c1e9-3924-46de-beb1-3b9046685257  2024.23
# 2      TID000003     MID0015  bd9c66b3-ad3c-4d6d-9a3d-1fa7bc8960a9  2981.36
# 3      TID000004     MID0043  972a8469-1641-4f82-8b9d-2434e465e150  1138.58
# 4      TID000005     MID0008  17fc695a-07a0-4a6e-8822-e8f36c031199  2336.92
#
#   currency payment_method   status        timestamp device_type location
# 0      INR     Debit Card  Success  5/27/2025 15:09         POS  Chennai
# 1      INR    Net Banking  Success   8/1/2025 17:51     Desktop     Pune
# 2      USD            UPI   Failed   6/5/2025 14:13         POS   Mumbai
# 3      INR     Debit Card  Success  6/23/2025 16:02      Mobile   Mumbai
# 4      INR    Credit Card  Success   7/19/2025 6:48      Mobile     Pune

# %%
df.tail()
# Out:
#      transaction_id merchant_id                           customer_id  \
# 4995      TID004996     MID0032  0f344fe1-c3c5-4bb5-a355-ce1655a47eab
# 4996      TID004997     MID0046  d11756d5-8c0d-4a8b-b448-a24723a86b61
# 4997      TID004998     MID0047  c1e158aa-ec96-4f27-9461-4433bbdf144c
# 4998      TID004999     MID0048  0ff4c2d6-e0d6-4081-a98d-c5f7a9d06567
# 4999      TID005000     MID0023  ce3fde9a-12aa-4ab4-be59-a0d13c5168b0
#
#        amount currency payment_method   status        timestamp device_type  \
# 4995  5943.89      INR            UPI  Success  6/22/2025 10:59     Desktop
# 4996  3916.68      INR    Credit Card  Success  4/20/2025 23:41         POS
# 4997  3426.00      INR     Debit Card  Success   4/13/2025 7:34         POS
# 4998  1972.94      INR    Credit Card   Failed   4/19/2025 8:47     Desktop
# 4999   685.92      INR     Debit Card  Success   7/13/2025 2:20      Mobile
#
#        location
# 4995       Pune
# 4996       Pune
# 4997    Chennai
# 4998  Bengaluru
# ...

# %%
df.sample(100)
# Out:
#      transaction_id merchant_id                           customer_id  \
# 2170      TID002171     MID0020  88a613b4-a3b8-4f92-a3c9-0c6a86017633
# 3105      TID003106     MID0044  6e411e23-7dd1-4b8f-aa05-5b69b4c04bdf
# 4830      TID004831     MID0047  93dc8eea-3e8e-436a-87e9-5e6d7f71eef6
# 4238      TID004239     MID0003  7bae0f3b-4c96-4dc2-8a41-aed81e2c6d4b
# 4745      TID004746     MID0024  b01ba134-544e-4743-8383-9f121335f6c3
# ...             ...         ...                                   ...
# 10        TID000011     MID0011  6c307511-b2b9-437a-a8df-6ec4ce4a2bbd
# 4960      TID004961     MID0032  73131038-b2df-4075-9b8f-abe952377d88
# 4565      TID004566     MID0010  e51bdfff-17aa-4aee-8dc2-0df3d49edd91
# 3243      TID003244     MID0050  9cac3d21-a5a8-48af-8efb-d22aec511744
# 4445      TID004446     MID0001  ee6c69f7-f8c9-4b4a-8d2f-2114da72ab37
#
#        amount currency payment_method   status        timestamp device_type  \
# ...

# %%
for col in df.columns:
    if df[col].dtype=='object':
      df[col].str.strip()

# %%
df
# Out:
#      transaction_id merchant_id                           customer_id  \
# 0         TID000001     MID0039  bdd640fb-0667-4ad1-9c80-317fa3b1799d
# 1         TID000002     MID0029  23b8c1e9-3924-46de-beb1-3b9046685257
# 2         TID000003     MID0015  bd9c66b3-ad3c-4d6d-9a3d-1fa7bc8960a9
# 3         TID000004     MID0043  972a8469-1641-4f82-8b9d-2434e465e150
# 4         TID000005     MID0008  17fc695a-07a0-4a6e-8822-e8f36c031199
# ...             ...         ...                                   ...
# 4995      TID004996     MID0032  0f344fe1-c3c5-4bb5-a355-ce1655a47eab
# 4996      TID004997     MID0046  d11756d5-8c0d-4a8b-b448-a24723a86b61
# 4997      TID004998     MID0047  c1e158aa-ec96-4f27-9461-4433bbdf144c
# 4998      TID004999     MID0048  0ff4c2d6-e0d6-4081-a98d-c5f7a9d06567
# 4999      TID005000     MID0023  ce3fde9a-12aa-4ab4-be59-a0d13c5168b0
#
#        amount currency payment_method   status        timestamp device_type  \
# ...

# %%
#Total vs successful transactions
successfull_transaction=df[df['status']=="Success"]

# %%
st=successfull_transaction.count()

# %%
total_transaction=df.count()

# %%
Total_successfultransactions=(st/total_transaction)*100

# %%
print(round(Total_successfultransactions))
# Out:
# transaction_id    87.0
# merchant_id       87.0
# customer_id       87.0
# amount            87.0
# currency          87.0
# payment_method    87.0
# status            87.0
# timestamp         87.0
# device_type       87.0
# location          87.0
# dtype: float64

# %%
#87% transaction are successfull

# %%
df['timestamp'] = pd.to_datetime(df['timestamp'])
df['year'] = df['timestamp'].dt.year
df['month'] = df['timestamp'].dt.month
df['day'] = df['timestamp'].dt.day
df['hour'] = df['timestamp'].dt.hour
df['day_of_week'] = df['timestamp'].dt.day_name()

# %%
#Monthly Transaction Volume
df.groupby('month')['amount'].sum().plot(kind='bar')
# Out:
# <Axes: xlabel='month'>

# %%
# Top Payment Methods
df['payment_method'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='payment_method'>

# %%
#Success vs Failed Rate
df['status'].value_counts(normalize=True).plot(kind='pie', autopct='%1.1f%%')
# Out:
# <Axes: ylabel='proportion'>

# %%
#Peak Transaction Hours
df.groupby('hour')['amount'].sum().plot(kind='line')
# Out:
# <Axes: xlabel='hour'>
